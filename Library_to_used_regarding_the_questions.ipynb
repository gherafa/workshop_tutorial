# %% [markdown]
# ##  Using GIS data with Python

# %% [markdown]
#     Import geopandas library

# %%
import geopandas as gpd

# %% [markdown]
#     Create dataframe with the name of "data" from a shapefile data located at my computer. You can replace the path to where your shapefile items are located in your computer.

# %%
data = gpd.read_file(r"E:\Harddisk\File Gheo\Vstudio\Python_OOP\Data\KECAMATAN_JABAR.shp")

# %% [markdown]
#     head() to check the first 5 element of a dataframe

# %%
data.head()
# Out:
#      ID   ID_Kec  Kecamatan      xcoord    ycoord kode_prop kode_kab  \
# 0  1700  3203150  Cimanggis  106.875724 -6.405124        32     3203
# 1  2023  3216010  Jatiluhur  107.353004 -6.563824        32     3216
# 2  2023  3216010  Jatiluhur  107.353004 -6.563824        32     3216
# 3  2061  3218110    Babelan  107.034897 -6.122316        32     3218
# 4  3265  3216031      Manis  107.321399 -6.682212        32     3216
#
#                                             geometry
# 0  POLYGON Z ((106.82195 -6.42883 0.00000, 106.82...
# 1  POLYGON Z ((107.28242 -6.63252 0.00000, 107.28...
# 2  POLYGON Z ((107.29162 -6.63786 0.00000, 107.28...
# 3  POLYGON Z ((107.02994 -6.05281 0.00000, 107.02...
# 4  POLYGON Z ((107.28601 -6.64203 0.00000, 107.28...

# %% [markdown]
# ### Plot the shapefile data using Python.

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Autocad in Python
#     I haven't figured out about how to read autocad file in python , but we can draw some shape in Python using PYAUTOCAD library, which i tried to install below. The shape the we create using that library in Python, the following shape will be added to your active autocad drawing.

# %%
# !pip install pyautocad
# Out:
# ...
#   Created wheel for pyautocad: filename=pyautocad-0.2.0-py3-none-any.whl size=11915 sha256=909ad3b7f053c49477d5953ca249793bbc1b7ed4d4754c7461593aef8a46e02c
#   Stored in directory: c:\users\gheo\appdata\local\pip\cache\wheels\56\a3\d4\efe27daa2174a475822d58ecb9ea6404f18ec52a0817724726
# Successfully built pyautocad
# ...

# %%
# importing pyautocad
import pyautocad
# creating AutoCAD instance
acad = pyautocad.Autocad()
